# %%
import pandas as pd
import numpy as np
frame =  pd.DataFrame.from_csv('PE-TRG-Jan-Mar-2017.csv').reset_index()

# %%
#get rows count by PLU
frame.groupby('PLU')[['PLU']].size().rename('counts').reset_index().sort_values(['counts'], ascending=[False])
# Out:
#          PLU  counts
# 458     2548   40667
# 425     2477   40607
# 427     2480   40551
# 499     2637   40435
# 460     2551   40424
# 247     2213   40360
# 210     2164   40255
# 309     2317   39803
# 323     2354   39323
# 322     2353   39302
# 267     2236   39243
# 468     2569   39105
# 640     3194   39048
# 300     2307   39029
# 255     2223   38956
# 244     2210   38845
# 462     2555   38737
# 301     2308   38658
# 467     2566   38603
# 455     2538   38470
# 303     2311   38317
# 456     2541   38061
# 232     2198   37961
# 475     2580   37403
# 534     2830   37222
# 431     2489   37186
# 637     3180   37133
# 480     2591   37107
# 270     2239   37097
# 446     2509   36850
# ...      ...     ...
# 4704  428588       1
# 4705  428589       1
# 1342  232292       1
# 731     3626       1
# 1338  232274       1
# 4723  428642       1
# 1333  231991       1
# 1330  231969       1
# 4748  428762       1
# 1327  231945       1
# 1319  231879       1
# ...

# %%
#get specific products
products = ['2548','2477','2480','2551','2637']
sales = frame[frame['PLU'].isin(products)]
sales

# %%
sales.to_csv('sales-jan-mar-2017.csv')

# %%
#get products info
sales.drop_duplicates(['RecipeName','PLU']).reset_index()[['RecipeName','PLU']].to_csv('products.csv')

# %%
#get locations
sales.drop_duplicates(['Locationid']).reset_index()[['Locationid']].to_csv('locations.csv')
