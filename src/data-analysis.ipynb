# %%
import pandas as pd
import numpy as np

# %%
# PE_cities.csv
# TRG_cities.csv
# TRG_location_287.csv - biggest file
df = pd.read_csv('../data/processed/TRG_location_287.csv', sep=';')
# remove zero qty because they are not changing quantity in stock
df = df[df.Quantity>0]
# remove negative and zero prices
#df = df[df.SalesPriceNet > 0]))
#print('SalesPrice<0:', len(df[df.SalesPrice < 0]))
#print('TotalSalesNet<0:', len(df[df.TotalSalesNet < 0]))
#print('TotalSales<0:', len(df[df.TotalSales < 0]))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171218 entries, 0 to 174258
# Data columns (total 24 columns):
# LocationID          171218 non-null int64
# LocationName        171218 non-null object
# RecipeName          171218 non-null object
# PLU                 171218 non-null int64
# SalesDate           171218 non-null object
# Quantity            171218 non-null float64
# SalesPriceNet       171218 non-null float64
# SalesPrice          171218 non-null float64
# TotalSalesNet       171218 non-null float64
# TotalSales          171218 non-null float64
# City1               0 non-null float64
# Country1            171218 non-null object
# Address1            171218 non-null object
# Address1PostCode    171218 non-null object
# City2               0 non-null float64
# Country2            0 non-null float64
# Address2            0 non-null float64
# Address2PostCode    0 non-null float64
# dt_year             171218 non-null int64
# dt_month            171218 non-null int64
# ...

# %%
print('rows:', len(df))
print('SalesPriceNet<0:', len(df[df.SalesPriceNet > 0]))
print('SalesPrice<0:', len(df[df.SalesPrice > 0]))
print('TotalSalesNet<0:', len(df[df.TotalSalesNet > 0]))
print('TotalSales<0:', len(df[df.TotalSales > 0]))
# Out:
# rows: 171218
# SalesPriceNet<0: 140866
# SalesPrice<0: 140861
# TotalSalesNet<0: 140866
# TotalSales<0: 140861

# %%
df.head(20)
# Out:
#     LocationID                       LocationName  \
# 0          287  F and B Sheffield Meadowhall 5182
# 1          287  F and B Sheffield Meadowhall 5182
# 2          287  F and B Sheffield Meadowhall 5182
# 3          287  F and B Sheffield Meadowhall 5182
# 4          287  F and B Sheffield Meadowhall 5182
# 5          287  F and B Sheffield Meadowhall 5182
# 6          287  F and B Sheffield Meadowhall 5182
# 7          287  F and B Sheffield Meadowhall 5182
# 8          287  F and B Sheffield Meadowhall 5182
# 10         287  F and B Sheffield Meadowhall 5182
# 11         287  F and B Sheffield Meadowhall 5182
# 12         287  F and B Sheffield Meadowhall 5182
# 14         287  F and B Sheffield Meadowhall 5182
# 15         287  F and B Sheffield Meadowhall 5182
# 16         287  F and B Sheffield Meadowhall 5182
# 17         287  F and B Sheffield Meadowhall 5182
# 18         287  F and B Sheffield Meadowhall 5182
# 19         287  F and B Sheffield Meadowhall 5182
# ...
